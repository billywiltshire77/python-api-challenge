# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q="
query = 'Chicago'
response = requests.get(f"{base_url}{query}").json()
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 41.85, 'lon': -87.65},
#  'dt': 1644179411,
#  'id': 4887398,
#  'main': {'feels_like': 25.38,
#           'humidity': 61,
#           'pressure': 1021,
#           'temp': 33.33,
#           'temp_max': 36.45,
#           'temp_min': 30.29},
#  'name': 'Chicago',
#  'sys': {'country': 'US',
#          'id': 2005153,
#          'sunrise': 1644152261,
#          'sunset': 1644189103,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 225, 'gust': 10, 'speed': 10}}

# %%
latitude = []
longitude = []
humidity = []
wind_speed = []
cloudiness = []
max_temp = []
city = []
country = []


for idx , row in enumerate(cities):
    try:
        response = requests.get(f"{base_url}{row}").json()
        latitude.append(round(response['coord']['lat'], 2))
        longitude.append(round(response['coord']['lon'], 2))
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        city.append(response['name'])
        country.append(response['sys']['country'])
        print(f"{idx}, {row}")
    except:
        print(f"{row} not found")
# Out:
# 0, porto novo
# 1, port alfred
# 2, westport
# 3, bluff
# 4, lebu
# 5, tuktoyaktuk
# 6, busselton
# 7, severo-kurilsk
# 8, udala
# 9, upernavik
# 10, san quintin
# 11, rikitea
# 12, tiksi
# 13, odweyne
# 14, east london
# 15, hilo
# 16, butaritari
# 17, kirakira
# 18, kodiak
# 19, punta arenas
# 20, vila velha
# 21, hermanus
# taolanaro not found
# 23, micheldorf
# 24, vaini
# 25, codrington
# 26, atuona
# 27, nome
# 28, emba
# 29, sampit
# 30, saint pete beach
# 31, bagan
# 32, cedar city
# 33, airai
# 34, maceio
# borama not found
# 36, hasaki
# 37, kahului
# 38, barrow
# 39, predivinsk
# 40, bengkulu
# 41, clyde river
# 42, bathsheba
# 43, skjervoy
# 44, puerto ayora
# 45, upata
# lolua not found
# 47, jamestown
# 48, sosnovskoye
# 49, yellowknife
# 50, manono
# 51, khagaria
# 52, saldanha
# 53, aykhal
# 54, labuhan
# 55, madang
# 56, esperance
# 57, mogadishu
# 58, pangnirtung
# 59, sioux lookout
# saleaula not found
# 61, pasichna
# 62, castro
# 63, mirnyy
# 64, saint-philippe
# 65, crossville
# 66, madoc
# 67, carnarvon
# 68, ola
# 69, itoman
# 70, namatanai
# 71, mataura
# meyungs not found
# 73, tasiilaq
# 74, touros
# 75, new norfolk
# 76, albany
# 77, mahebourg
# 78, erenhot
# 79, jinchang
# 80, tatawin
# 81, katsuura
# 82, thompson
# 83, dikson
# 84, ushuaia
# ambodifototra not found
# 86, bambous virieux
# 87, bredasdorp
# 88, robertsport
# 89, arraial do cabo
# 90, palaikastron
# 91, bethel
# 92, keroka
# 93, maralal
# 94, camacha
# 95, torbay
# 96, peniche
# 97, amursk
# 98, cherskiy
# 99, nikolskoye
# 100, cabo san lucas
# 101, axim
# 102, port elizabeth
# 103, entre rios
# 104, sao filipe
# 105, waitati
# 106, port augusta
# 107, khatanga
# 108, avarua
# 109, kaitangata
# 110, batagay-alyta
# illoqqortoormiut not found
# 112, tessalit
# 113, huambo
# 114, otavi
# 115, bandarbeyla
# 116, ciudad bolivar
# 117, mangaratiba
# 118, panama city
# 119, ribeira grande
# 120, grootfontein
# barentsburg not found
# 122, qaanaaq
# 123, saint-joseph
# 124, tura
# 125, chokurdakh
# 126, carutapera
# 127, the valley
# 128, dayong
# 129, souillac
# 130, talnakh
# 131, cape town
# grand river south east not found
# 133, alta floresta
# 134, hervey bay
# 135, ust-maya
# 136, padang
# 137, geraldton
# 138, cayenne
# 139, nouadhibou
# 140, fukue
# 141, chuy
# 142, guarapari
# 143, saint anthony
# 144, leningradskiy
# 145, marathon
# 146, port lincoln
# halalo not found
# 148, tilichiki
# 149, matagami
# 150, sacramento
# 151, gari
# 152, elko
# 153, kuah
# 154, hamilton
# 155, georgetown
# 156, urubicha
# 157, provideniya
# 158, saskylakh
# vaitupu not found
# 160, whitianga
# 161, sosva
# 162, dudinka
# sentyabrskiy not found
# 164, hithadhoo
# 165, narsaq
# 166, srednekolymsk
# 167, lysyye gory
# 168, taldan
# 169, vanavara
# 170, shangrao
# 171, grindavik
# 172, presidencia roque saenz pena
# tsihombe not found
# 174, jumla
# 175, razdolinsk
# 176, leh
# 177, la ronge
# mys shmidta not found
# 179, torquay
# 180, lasa
# 181, mar del plata
# 182, kapaa
# 183, krasnoselkup
# 184, victoria
# 185, moose factory
# 186, dingle
# 187, artvin
# 188, hong gai
# 189, poum
# 190, oranjemund
# 191, khudumelapye
# 192, hobart
# 193, belmonte
# 194, karasburg
# 195, sfantu gheorghe
# skalistyy not found
# 197, mabaruma
# 198, lagoa
# 199, banda aceh
# samusu not found
# 201, alice springs
# 202, blagoyevo
# 203, ancud
# 204, canberra
# tumannyy not found
# 206, kununurra
# 207, nelson bay
# 208, cockburn town
# 209, camana
# 210, qasigiannguit
# satitoa not found
# 212, hambantota
# 213, hualmay
# 214, scarborough
# 215, lompoc
# 216, lavrentiya
# 217, taltal
# 218, anadyr
# 219, dabat
# 220, mackay
# 221, bongandanga
# 222, bang saphan
# 223, voh
# 224, cabinda
# 225, leningradskaya
# 226, turukhansk
# 227, anyang
# 228, norman wells
# 229, inhambane
# 230, ambon
# 231, mysen
# 232, maumere
# 233, bairiki
# 234, lucea
# 235, lasem
# 236, olafsvik
# 237, fortuna
# 238, rabo de peixe
# 239, xining
# 240, suicheng
# 241, paamiut
# 242, ponta do sol
# 243, chernyshevskiy
# 244, tuatapere
# 245, nuuk
# 246, komsomolskiy
# dujuma not found
# 248, boyolangu
# 249, auki
# 250, yulara
# 251, nakatsugawa
# nizhneyansk not found
# 253, portland
# khonuu not found
# 255, saint-denis
# 256, kolokani
# 257, tawau
# 258, liverpool
# 259, dowa
# 260, mehamn
# 261, nago
# 262, salalah
# 263, fairbanks
# 264, ostrovnoy
# 265, rio gallegos
# 266, kanniyakumari
# amderma not found
# 268, jamsa
# 269, cedar falls
# tabiauea not found
# 271, muzhi
# 272, ardakan
# 273, comodoro rivadavia
# 274, san jose
# 275, tapes
# 276, te anau
# 277, kismayo
# attawapiskat not found
# 279, vardo
# 280, narasannapeta
# samalaeulu not found
# 282, makhinjauri
# 283, san patricio
# 284, canaries
# 285, vyshestebliyevskaya
# bolshaya murta not found
# 287, ust-omchug
# 288, helena
# 289, northam
# 290, kristinehamn
# 291, puerto baquerizo moreno
# 292, nanortalik
# 293, gushikawa
# kamenskoye not found
# 295, bintulu
# 296, west odessa
# 297, sola
# 298, puerto escondido
# 299, atar
# 300, sonoita
# 301, antalya
# 302, kavaratti
# 303, sechura
# 304, nawabganj
# 305, tahta
# 306, kavieng
# 307, kalmunai
# 308, belyy
# 309, cidreira
# 310, salisbury
# 311, kouroussa
# 312, jiayuguan
# bolungarvik not found
# 314, berlevag
# 315, asau
# tidore not found
# 317, araouane
# 318, nikolayevsk-na-amure
# 319, jonkoping
# 320, lokosovo
# 321, bataipora
# 322, luderitz
# 323, harper
# 324, kamenka
# 325, nhulunbuy
# 326, conceicao do araguaia
# 327, pacific grove
# labutta not found
# 329, necochea
# belushya guba not found
# 331, baruun-urt
# 332, alyangula
# 333, corinto
# 334, palmer
# 335, panambi
# 336, sobolevo
# 337, kigoma
# 338, badulla
# 339, dong hoi
# 340, hay river
# 341, beyneu
# 342, college
# 343, mucurapo
# 344, adrar
# 345, caluquembe
# 346, genhe
# 347, ushtobe
# 348, sorong
# 349, porto tolle
# 350, mecca
# 351, rapar
# 352, praia
# 353, vikulovo
# 354, bilibino
# 355, swan hill
# 356, caravelas
# 357, marsa matruh
# 358, krasnyy
# 359, mikkeli
# sorvag not found
# 361, hurricane
# 362, boffa
# 363, evensk
# 364, medea
# 365, olinda
# 366, pathein
# 367, saint-augustin
# 368, anito
# 369, teguise
# 370, binzhou
# 371, kattivakkam
# 372, chiredzi
# 373, grand-santi
# 374, pontes e lacerda
# 375, guerrero negro
# 376, urengoy
# 377, puerto madryn
# 378, mendi
# doctor pedro p. pena not found
# 380, lithgow
# 381, stanger
# 382, hami
# 383, saratovskaya
# 384, marshall
# 385, klaksvik
# 386, port hardy
# 387, weiser
# 388, north bend
# 389, karratha
# 390, praia da vitoria
# 391, saint george
# 392, pamyat parizhskoy kommuny
# 393, xique-xique
# 394, imeni zhelyabova
# 395, mount isa
# 396, beloha
# 397, wanning
# 398, flin flon
# 399, kiama
# 400, lieksa
# 401, lorengau
# 402, puerto leguizamo
# 403, cavite
# 404, port hawkesbury
# 405, darhan
# kinanah not found
# rungata not found
# 408, gaoua
# 409, changji
# 410, sao jose da coroa grande
# 411, angoche
# 412, bambanglipuro
# 413, sitka
# 414, pevek
# 415, broome
# 416, rampura
# 417, batemans bay
# 418, puqi
# 419, siparia
# 420, altay
# 421, areosa
# 422, pontiac
# 423, omboue
# 424, klyuchi
# bargal not found
# 426, yuli
# 427, mayo
# 428, goderich
# 429, bojonegoro
# 430, havelock
# nguiu not found
# 432, waingapu
# 433, houma
# 434, hofn
# 435, pestovo
# 436, haines junction
# 437, rypin
# 438, iskateley
# 439, ilulissat
# 440, steinkjer
# 441, colares
# 442, abong mbang
# 443, yeppoon
# 444, weston
# 445, baykit
# 446, kysyl-syr
# 447, lagunillas
# 448, oktyabrskoye
# 449, pitsunda
# 450, faanui
# 451, dawei
# 452, kungurtug
# 453, santa helena de goias
# 454, melk
# 455, nacala
# 456, lethem
# 457, manggar
# 458, tromso
# karauzyak not found
# huazolotitlan not found
# 461, ulladulla
# 462, galveston
# 463, pedro betancourt
# 464, deputatskiy
# aflu not found
# 466, antalaha
# 467, zyryanskoye
# 468, ketchikan
# 469, cody
# 470, anloga
# 471, pareora
# 472, port hueneme
# 473, marzuq
# 474, vaitape
# 475, yeniseysk
# 476, imbituba
# 477, raga
# 478, winchester
# 479, korla
# 480, fuyang
# 481, cordoba
# 482, vila franca do campo
# 483, namibe
# 484, husavik
# 485, los llanos de aridane
# 486, alfiousa
# 487, muros
# 488, zyryanka
# 489, san cristobal
# 490, weinan
# 491, longyearbyen
# dipkarpaz not found
# 493, imeni poliny osipenko
# 494, columbia
# 495, flinders
# 496, malacacheta
# 497, ndende
# 498, debica
# 499, sayyan
# 500, huilong
# 501, brigantine
# 502, marawi
# 503, buta
# 504, san vicente
# 505, taksimo
# chagda not found
# 507, nambour
# 508, pietarsaari
# 509, port hedland
# 510, bria
# 511, prince rupert
# 512, gold coast
# 513, luanda
# 514, strib
# 515, juegang
# 516, ati
# 517, dubbo
# 518, mercedes
# 519, guryevsk
# 520, zhigansk
# 521, muravlenko
# 522, magadan
# 523, aksu
# 524, arauca
# 525, dutse
# 526, kedrovyy
# 527, nishihara
# 528, kampot
# 529, dumas
# 530, edd
# 531, aranos
# lephepe not found
# 533, zabol
# 534, garissa
# 535, ahipara
# 536, celestun
# 537, freeport
# 538, iracoubo
# 539, grevenbroich
# haibowan not found
# 541, whittlesea
# 542, mastic beach
# 543, fairmont
# 544, rohnert park
# 545, zinder
# 546, champerico
# 547, richards bay
# 548, arlit
# 549, dunedin
# 550, manaure
# 551, isla vista
# 552, tuy hoa
# 553, torrington
# 554, encruzilhada
# 555, jining
# 556, skara
# 557, penzance
# 558, quatre cocos
# 559, dalvik
# 560, kruisfontein
# kazalinsk not found
# 562, rio grande
# tabukiniberu not found
# 564, ingham
# 565, marigot
# 566, freetown
# vitimskiy not found
# 568, pangkalanbuun
# 569, zunyi
# 570, erzin
# 571, tretten
# marcona not found
# 573, fomboni
# 574, cairns
# 575, meadow lake
# grand centre not found
# 577, vallenar
# 578, sembakung
# 579, kano
# rawannawi not found
# 581, kieta
# 582, kloulklubed
# 583, jiwani
# 584, zhuhai
# 585, aswan
# 586, sar-e pul
# 587, danville
# 588, krasnoarmeysk
# 589, rozkishne
# 590, manavalakurichi
# 591, messina
# 592, viedma
# 593, campbell river
# 594, teshie
# 595, baiyin
# 596, awjilah
# 597, anamur
# 598, saint-pierre
# 599, ulaangom
# 600, kushima
# 601, kenai
# 602, mvuma

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame({
        "City": city,
        "Country": country,
        "Longitude": longitude,
        "Latitude": latitude,
        "Humidity (%)": humidity,
        "Wind Speed (mph)": wind_speed,
        "Cloudiness (%)": cloudiness,
        "Max Temp (f)": max_temp
})
df.head()
# Out:
#           City Country  Longitude  Latitude  Humidity (%)  Wind Speed (mph)  \
# 0   Porto-Novo      BJ       2.60      6.50            82              6.55
# 1  Port Alfred      ZA      26.89    -33.59            82             14.05
# 2     Westport      US     -73.36     41.14            62              1.01
# 3        Bluff      NZ     168.33    -46.60            66              5.17
# 4         Lebu      CL     -73.65    -37.62            69             13.51
#
#    Cloudiness (%)  Max Temp (f)
# 0              11         84.02
# 1              82         74.70
# 2              76         32.32
# 3               2         54.81
# 4               0         65.19

# %%
df.to_csv(output_data_file)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
over_humid = df.loc[df['Humidity (%)'] > 100, :]
len(over_humid)
# Out:
# 0

# %%
#  Get the indices of cities that have humidity over 100%.
#not necessary since len of df above is 0
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(df['Latitude'], df['Max Temp (f)'])
plt.xlabel('Latitude')
plt.ylabel('Max Temp (f)')
plt.title('Max Temperature (f) vs. Latitude')
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(df['Latitude'], df['Humidity (%)'])
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Humidity (%) vs. Latitude')
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(df['Latitude'], df['Cloudiness (%)'])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Cloudiness (%) vs. Latitude')
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(df['Latitude'], df['Wind Speed (mph)'])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Wind Speed (mph) vs. Latitude')
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Creates DFs for North and South Hemispheres
north_df = df.loc[df['Latitude'] >= 0, :]
south_df = df.loc[df['Latitude'] < 0, :]

# %%
#(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_df['Latitude']
y_values = north_df['Max Temp (f)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = (slope * x_values) + intercept
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Tem (f)')
plt.title('Northern Hemisphere Max Temp (f) vs. Latitude')
plt.plot(x_values, line, c='r')
plt.annotate(f'y={round(slope, 2)}x + {round(intercept,2)}', (0,-30), c='r',size=15)
print(f'The R Value is: {rvalue}')
plt.show()
# Out:
# The R Value is: -0.8523155121189417

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_df['Latitude']
y_values = south_df['Max Temp (f)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = (slope * x_values) + intercept
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Tem (f)')
plt.title('Souther Hemisphere Max Temp (f) vs. Latitude')
plt.plot(x_values, line, c='r')
plt.annotate(f'y={round(slope, 2)}x + {round(intercept,2)}', (-25,55), c='r',size=15)
print(f'The R Value is: {rvalue}')
plt.show()
# Out:
# The R Value is: 0.5374032880130454

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_df['Latitude']
y_values = north_df['Humidity (%)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = (slope * x_values) + intercept
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere Humidity % vs. Latitude')
plt.plot(x_values, line, c='r')
plt.annotate(f'y={round(slope, 2)}x + {round(intercept,2)}', (45,25), c='r',size=15)
print(f'The R Value is: {rvalue}')
plt.show()
# Out:
# The R Value is: 0.36885118982459003

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_df['Latitude']
y_values = south_df['Humidity (%)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = (slope * x_values) + intercept
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere Humidity % vs. Latitude')
plt.plot(x_values, line, c='r')
plt.annotate(f'y={round(slope, 2)}x + {round(intercept,2)}', (-25,35), c='r',size=15)
print(f'The R Value is: {rvalue}')
plt.show()
# Out:
# The R Value is: 0.3613975543759063

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_df['Latitude']
y_values = north_df['Cloudiness (%)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = (slope * x_values) + intercept
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere Cloudiness % vs. Latitude')
plt.plot(x_values, line, c='r')
plt.annotate(f'y={round(slope, 2)}x + {round(intercept,2)}', (45,40), c='r',size=15)
print(f'The R Value is: {rvalue}')
plt.show()
# Out:
# The R Value is: 0.20661969133209215

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_df['Latitude']
y_values = south_df['Cloudiness (%)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = (slope * x_values) + intercept
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere Cloudiness % vs. Latitude')
plt.plot(x_values, line, c='r')
plt.annotate(f'y={round(slope, 2)}x + {round(intercept,2)}', (-55,25), c='r',size=15)
print(f'The R Value is: {rvalue}')
plt.show()
# Out:
# The R Value is: 0.38672005274951626

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_df['Latitude']
y_values = north_df['Wind Speed (mph)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = (slope * x_values) + intercept
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere Wind Speed (mph) vs. Latitude')
plt.plot(x_values, line, c='r')
plt.annotate(f'y={round(slope, 2)}x + {round(intercept,2)}', (0, 30), c='r',size=15)
print(f'The R Value is: {rvalue}')
plt.show()
# Out:
# The R Value is: 0.06288029968199864

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_df['Latitude']
y_values = south_df['Wind Speed (mph)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line = (slope * x_values) + intercept
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere Wind Speed (mph) vs. Latitude')
plt.plot(x_values, line, c='r')
plt.annotate(f'y={round(slope, 2)}x + {round(intercept,2)}', (-55, 25), c='r',size=15)
print(f'The R Value is: {rvalue}')
plt.show()
# Out:
# The R Value is: -0.17556619689616298
